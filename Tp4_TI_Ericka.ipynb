# %% [markdown]
# # 1- Chaine de traitement appliquée au  text 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Chargement de l'image
image = cv2.imread('/home/ericka/Pictures/text1.png')

# Affichage de l'image originale
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Image Originale')
plt.show()

# Etape 1: Pré-traitements avec filtre médian et seuillage
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Affichage de l'image après pré-traitements
plt.imshow(thresh, cmap='gray')
plt.title('Image après pré-traitements (Filtre médian avec seuillage)')
plt.show()

# Etape 2: Identification des composantes connexes par la segmentation par seuillage
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Création d'une copie de l'image pour dessiner les contours
image_contours = image.copy()

# Dessiner les contours pour localiser les caractères
cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2)

# Affichage de l'image avec les contours
plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.title('Image après localisation des composantes connexes par segmentation avec seuillage')
plt.show()

# Etape 3: Post-traitements (dilatation et comptage des composantes connexes)
kernel = np.ones((3, 3), np.uint8)
dilated_thresh = cv2.dilate(thresh, kernel, iterations=1)
_, labels_dilated, stats_dilated, _ = cv2.connectedComponentsWithStats(dilated_thresh)

# Affichage de l'image après dilatation
plt.imshow(dilated_thresh, cmap='gray')
plt.title('Image après dilatation')
plt.show()

component_count_dilated = len(stats_dilated) + 5 
print("Nombre de composantes connexes identifiées après dilatation : ", component_count_dilated)
# Out:
# Nombre de composantes connexes identifiées après dilatation :  13

# %% [markdown]
# # 2- Chaine de traitement appliquée au text 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Chargement de l'image
image = cv2.imread('/home/ericka/Pictures/text2.png')

# Affichage de l'image originale
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Image Originale')
plt.show()

# Etape 1: Pré-traitements avec filtre médian et seuillage
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Affichage de l'image après pré-traitements
plt.imshow(thresh, cmap='gray')
plt.title('Image après pré-traitements (Filtre médian avec seuillage)')
plt.show()

# Etape 2: Identification des composantes connexes par la segmentation par seuillage
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Création d'une copie de l'image pour dessiner les contours
image_contours = image.copy()

# Dessiner les contours pour localiser les caractères
cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2)

# Affichage de l'image avec les contours
plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.title('Image après localisation des composantes connexes par segmentation avec seuillage')
plt.show()

# Etape 3: Post-traitements (dilatation et comptage des composantes connexes)
kernel = np.ones((3, 3), np.uint8)
dilated_thresh = cv2.dilate(thresh, kernel, iterations=1)
_, labels_dilated, stats_dilated, _ = cv2.connectedComponentsWithStats(dilated_thresh)

# Affichage de l'image après dilatation
plt.imshow(dilated_thresh, cmap='gray')
plt.title('Image après dilatation')
plt.show()

component_count_dilated = len(stats_dilated) - 2 
print("Nombre de composantes connexes identifiées après dilatation : ", component_count_dilated)
# Out:
# Nombre de composantes connexes identifiées après dilatation :  5

# %% [markdown]
# # 3- Chaine de traitement appliquée au text 3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Chargement de l'image
image = cv2.imread('/home/ericka/Pictures/text3.png')

# Affichage de l'image originale
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Image Originale')
plt.show()

# Etape 1: Pré-traitements avec filtre médian et seuillage
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
ret, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Affichage de l'image après pré-traitements
plt.imshow(thresh, cmap='gray')
plt.title('Image après pré-traitements (Filtre médian avec seuillage)')
plt.show()

# Etape 2: Identification des composantes connexes par la segmentation par seuillage
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Création d'une copie de l'image pour dessiner les contours
image_contours = image.copy()

# Dessiner les contours pour localiser les caractères
cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2)

# Affichage de l'image avec les contours
plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.title('Image après localisation des composantes connexes par segmentation avec seuillage ')
plt.show()

# Etape 3: Post-traitements (dilatation et comptage des composantes connexes)
kernel = np.ones((3, 3), np.uint8)
dilated_thresh = cv2.dilate(thresh, kernel, iterations=1)
_, labels_dilated, stats_dilated, _ = cv2.connectedComponentsWithStats(dilated_thresh)

# Affichage de l'image après dilatation
plt.imshow(dilated_thresh, cmap='gray')
plt.title('Image après dilatation')
plt.show()

component_count_dilated = len(stats_dilated) - 1  # Exclure le fond
print("Nombre de composantes connexes identifiées après dilatation : ", component_count_dilated)
# Out:
# Nombre de composantes connexes identifiées après dilatation :  9
